# %% [markdown]
# # 인공지능이론 및 프로그래밍 실습강의4

# %% [markdown]
# # matplotlib
#
# https://matplotlib.org/

# %% [markdown]
# ![image.png](data:image/png;base64,...)Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python.
#
# screenshotsscreenshotsscreenshotsscreenshots
# Matplotlib makes easy things easy and hard things possible.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X = np.linspace(0, 4*np.pi, 1000)
Y = np.sin(X)
print(X)

# %%
plt.plot(X, Y)
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot(X, Y)
fig.show()

# %%
X = np.random.uniform(0, 1, 100)
Y = np.random.uniform(0, 1, 100)

fig, ax = plt.subplots()
ax.scatter(X, Y)
fig.show()

# %%
X = np.arange(10)
Y = np.random.uniform(1, 10, 10)

fig, ax = plt.subplots()
ax.bar(X,Y)
fig.show()

# %%
X = np.arange(10)
Y = np.random.uniform(1, 10, 10)

fig, ax = plt.subplots()
ax.barh(X,Y)
fig.show()

# %%
Z = np.random.uniform(0, 1, (8,8))

fig, ax = plt.subplots()
img = ax.imshow(Z)
fig.show()

# %%
Z = np.random.uniform(0, 1, (8,8))

fig, ax = plt.subplots()
img = ax.imshow(Z)
fig.colorbar(img, label='color')
fig.show()

# %%
Z = np.random.uniform(0, 1, (8,8))

fig, ax = plt.subplots()
img = ax.contourf(Z)
fig.colorbar(img, label='color')
fig.show()

# %%
def f(x, y): 
    return (x * x) - (y * y) - 1
    #Hyperbola

n = 200
x = np.linspace(-10, 10, n)
y = np.linspace(-10, 10, n)
XX, YY = np.meshgrid(x, y)
ZZ = f(XX, YY)

plt.title("Contour plots")``
plt.contourf(XX, YY, ZZ)
plt.contour(XX, YY, ZZ, colors='black')
plt.show()

# %%
def f(x, y): 
    return (x * x) - (y * y) - 1
    #Hyperbola

n = 200
x = np.linspace(-10, 10, n)
y = np.linspace(-10, 10, n)
XX, YY = np.meshgrid(x, y)
ZZ = f(XX, YY)

fig, ax = plt.subplots()

ax.set_title("Contour plots")
subplot = ax.contourf(XX, YY, ZZ)
ax.contour(XX, YY, ZZ, colors='black')
ax.set_aspect('equal')
fig.colorbar(subplot, label='Value')
fig.show()

# %%
Z = [10,20,30,40]
plt.pie(Z)
plt.show()

# %%
Z = [10,20,30,40]
plt.pie(Z, labels=['blue','orange','green','red'], autopct='%1.1f%%')
plt.show()

# %%
Z = np.random.normal(0, 1, 1000) # mean, standard deviation, array size
fig, ax = plt.subplots()
ax.hist(Z)
fig.show()

# %%
Z = np.random.normal(0, 1, 1000)
Z2 = np.random.normal(5, 1, 1000)
fig, ax = plt.subplots()
ax.hist(Z, color = "red", alpha=0.7)
ax.set_title("Histograms")
ax.hist(Z2, color = "green", alpha=0.7)
fig.show()

# %%
Z = np.random.normal(0,1,(100,3))

fig, ax = plt.subplots()
ax.boxplot(Z)
fig.show()

# %%
X = np.linspace(0, 4*np.pi, 1000)
Y = np.sin(X)
fig, ax = plt.subplots()
ax.plot(X, Y)
fig.show()

# %%
X = np.linspace(0, 4*np.pi, 1000)
Y = np.sin(X)
fig, ax = plt.subplots()
ax.plot(X, Y, color = "black")
fig.show()

# %%
X = np.linspace(0, 4*np.pi, 1000)
Y = np.sin(X)
fig, ax = plt.subplots()
ax.plot(X, Y, color="orange", linestyle="--")
fig.show()

# %%
X = np.linspace(0, 4*np.pi, 1000)
Y = np.sin(X)
fig, ax = plt.subplots()
ax.plot(X, Y, color="orange", linestyle="--", linewidth="5")
fig.show()

# %%
X = np.linspace(0, 4*np.pi, 100)
Y = np.sin(X)
fig, ax = plt.subplots()
ax.plot(X, Y, color="orange", linestyle="--", linewidth="1", marker="x")
fig.show()

# %%
X = np.linspace(0, 4*np.pi, 100)
Y1 = np.sin(X)
Y2 = np.cos(X)
fig, ax = plt.subplots()
ax.plot(X, Y1, color="green", linewidth="3", label="sin")
ax.plot(X, Y2, color="red", linewidth="3", label="cos")
fig.legend()
fig.show()

# %%
X = np.linspace(0, 4*np.pi, 100)
Y1 = np.sin(X)
Y2 = np.cos(X)
fig, ax = plt.subplots()
ax.plot(X, Y1, color="green", linewidth="3", label="sin")
ax.plot(X, Y2, color="red", linewidth="3", label="cos")
ax.set_title("Sine & Cosine")
fig.legend(loc="upper left",ncol=2)
fig.show()

# %%
X = np.linspace(0, 4*np.pi, 100)
Y1 = np.sin(X)
Y2 = np.cos(X)
fig, ax = plt.subplots()
ax.plot(X, Y1, color="green", linewidth="3", label="sin")
ax.plot(X, Y2, color="red", linewidth="3", label="cos")
ax.set_xlabel("X", size=15)
ax.set_ylabel("f(X)", size=15)
ax.set_title("Sine & Cosine", size=20)
fig.legend(loc="upper left",ncol=2)
fig.show()

# %%
X = np.linspace(0, 4*np.pi, 100)
Y1 = np.sin(X)
Y2 = np.cos(X)
fig, ax = plt.subplots()
ax.plot(X, Y1, color="green", linewidth="3", label="sin")
ax.plot(X, Y2, color="red", linewidth="3", label="cos")
ax.set_xlabel("X", size=15)
ax.set_ylabel("f(X)", size=15)
ax.set_title("Sine & Cosine", size=20)
ax.annotate("Something special!",(X[30],Y1[30]),(X[50],Y1[70]),ha='center', va='center', arrowprops = {"arrowstyle": "->", "color" : "black", "linewidth":"3"})
fig.legend(loc="upper left",ncol=2)
fig.show()

# %%
X = np.linspace(0, 4*np.pi, 100)
Y1 = np.sin(X)
Y2 = np.cos(X)
fig, axs = plt.subplots(1,2)
axs[0].plot(X, Y1, color="green", linewidth="3", label="sin")
axs[1].plot(X, Y2, color="red", linewidth="3", label="cos")
# ax.set_xlabel("X", size=15)
# ax.set_ylabel("f(X)", size=15)
# ax.set_title("Sine & Cosine", size=20)
fig.legend(loc="upper left",ncol=2)
fig.show()

# %%
X = np.linspace(0, 4*np.pi, 100)
Y1 = np.sin(X)
Y2 = np.cos(X)
Y3 = np.exp(X)
Y4 = X * X
fig, axs = plt.subplots(2,2)
axs[0, 0].plot(X, Y1, color="green", linewidth="3", label="sin")
axs[0, 1].plot(X, Y2, color="red", linewidth="3", label="cos")
axs[1, 0].plot(X, Y3, color="blue", linewidth="3", label="exp(X)")
axs[1, 1].plot(X, Y4, color="orange", linewidth="3", label="X^2")
fig.legend(loc="upper left",ncol=2)
fig.show()

# %%
X = np.linspace(0, 4*np.pi, 100)
Y1 = np.sin(X)
Y2 = np.cos(X)
Y3 = np.exp(X)
Y4 = X * X
fig, axs = plt.subplots(2,2, figsize=(10,8)) # figsize => inch를 사용
axs[0, 0].plot(X, Y1, color="green", linewidth="3", label="sin")
axs[0, 1].plot(X, Y2, color="red", linewidth="3", label="cos")
axs[1, 0].plot(X, Y3, color="blue", linewidth="3", label="exp(X)")
axs[1, 1].plot(X, Y4, color="orange", linewidth="3", label="X^2")
fig.tight_layout()
fig.legend(loc="upper left",ncol=2)
fig.show()

# %%
X = np.linspace(0, 4*np.pi, 100)
Y1 = np.sin(X)
Y2 = np.cos(X)
Y3 = np.exp(X)
Y4 = X * X
fig, axs = plt.subplots(2,2, figsize=(10,8))
axs[0, 0].plot(X, Y1, color="green", linewidth="3", label="sin")
axs[0, 0].legend(loc="upper left")
axs[0, 1].plot(X, Y2, color="red", linewidth="3", label="cos")
axs[0, 1].legend(loc="upper left")
axs[1, 0].plot(X, Y3, color="blue", linewidth="3", label="exp(X)")
axs[1, 0].legend(loc="upper left")
axs[1, 1].plot(X, Y4, color="orange", linewidth="3", label="X^2")
axs[1, 1].legend(loc="upper left")
fig.tight_layout()

fig.show()

# %%
X = np.linspace(0, 4*np.pi, 100)
Y1 = np.sin(X)
Y2 = np.cos(X)
Y3 = np.exp(X)
Y4 = X * X

plt.style.use("grayscale")

fig, axs = plt.subplots(2,2, figsize=(10,8))
axs[0, 0].plot(X, Y1, color="green", linewidth="3", label="sin")
axs[0, 0].legend(loc="upper left")
axs[0, 1].plot(X, Y2, color="red", linewidth="3", label="cos")
axs[0, 1].legend(loc="upper left")
axs[1, 0].plot(X, Y3, color="blue", linewidth="3", label="exp(X)")
axs[1, 0].legend(loc="upper left")
axs[1, 1].plot(X, Y4, color="orange", linewidth="3", label="X^2")
axs[1, 1].legend(loc="upper left")
fig.tight_layout()
fig.show()

# %%
#Text & scale!!
X = np.linspace(0, 4*np.pi, 100)
Y1 = np.sin(X)
Y2 = np.cos(X)
Y3 = np.exp(X)
Y4 = X * X

plt.style.use("default")

fig, axs = plt.subplots(2,2, figsize=(10,8))
axs[0, 0].plot(X, Y1, color="green", linewidth="3", label="sin")
axs[0, 0].legend(loc="upper left")
axs[0, 1].plot(X, Y2, color="red", linewidth="3", label="cos")
axs[0, 1].legend(loc="upper left")


axs[1, 0].plot(X, Y3, color="blue", linewidth="3", label="exp(X)")
axs[1, 0].legend(loc="upper left")
axs[1, 0].set_yscale("log")


axs[1, 1].plot(X, Y4, color="orange", linewidth="3", label="X^2")
axs[1, 1].legend(loc="upper left")
axs[1, 1].text(2.5, 82.5, "Hi!")
fig.tight_layout()
fig.show()

# %%
from matplotlib import ticker

# %%
X = np.linspace(0, 4*np.pi, 100)
Y1 = np.sin(X)
Y2 = np.cos(X)
Y3 = np.exp(X)
Y4 = X * X

plt.style.use("default")

fig, axs = plt.subplots(2,2, figsize=(10,8))
axs[0, 0].plot(X, Y1, color="green", linewidth="3", label="sin")
axs[0, 0].legend(loc="upper left")


axs[0, 0].xaxis.set_major_locator(ticker.NullLocator())
axs[0, 0].yaxis.set_major_locator(ticker.LinearLocator(numticks=3))


axs[0, 1].plot(X, Y2, color="red", linewidth="3", label="cos")
axs[0, 1].legend(loc="upper left")
axs[1, 0].plot(X, Y3, color="blue", linewidth="3", label="exp(X)")
axs[1, 0].legend(loc="upper left")
axs[1, 0].set_yscale("log")
axs[1, 1].plot(X, Y4, color="orange", linewidth="3", label="X^2")
axs[1, 1].legend(loc="upper left")
fig.tight_layout()
fig.show()

# %%
X = np.linspace(0, 4*np.pi, 100)
Y1 = np.sin(X)
Y2 = np.cos(X)
Y3 = np.exp(X)
Y4 = X * X

plt.style.use("default")

fig, axs = plt.subplots(2,2, figsize=(10,8))
axs[0, 0].plot(X, Y1, color="green", linewidth="3", label="sin")
axs[0, 0].legend(loc="upper left")
axs[0, 0].xaxis.set_major_locator(ticker.NullLocator())
axs[0, 0].set_ylim(-1,1)
axs[0, 0].yaxis.set_major_locator(ticker.LinearLocator(numticks=3))
axs[0, 1].plot(X, Y2, color="red", linewidth="3", label="cos")
axs[0, 1].legend(loc="upper left")
axs[1, 0].plot(X, Y3, color="blue", linewidth="3", label="exp(X)")
axs[1, 0].legend(loc="upper left")
axs[1, 0].set_yscale("log")
axs[1, 1].plot(X, Y4, color="orange", linewidth="3", label="X^2")
axs[1, 1].legend(loc="upper left")
fig.tight_layout()
fig.show()

# %%
X = np.linspace(0, 4*np.pi, 100)
Y1 = np.sin(X)
Y2 = np.cos(X)
Y3 = np.exp(X)
Y4 = X * X

plt.style.use("default")

fig, axs = plt.subplots(2,2, figsize=(10,8))
axs[0, 0].plot(X, Y1, color="green", linewidth="3", label="sin")
axs[0, 0].legend(loc="upper left")
axs[0, 0].xaxis.set_major_locator(ticker.NullLocator())
axs[0, 0].set_ylim(-1,1)
axs[0, 0].yaxis.set_major_locator(ticker.LinearLocator(numticks=3))
axs[0, 1].plot(X, Y2, color="red", linewidth="3", label="cos")
axs[0, 1].xaxis.set_major_formatter(ticker.PercentFormatter(xmax=2*np.pi))
axs[0, 1].legend(loc="upper left")
axs[1, 0].plot(X, Y3, color="blue", linewidth="3", label="exp(X)")
axs[1, 0].legend(loc="upper left")
axs[1, 0].set_yscale("log")
axs[1, 1].plot(X, Y4, color="orange", linewidth="3", label="X^2")
axs[1, 1].legend(loc="upper left")
fig.tight_layout()
fig.show()

# %%
X = np.linspace(0, 4*np.pi, 100)
Y1 = np.sin(X)
Y2 = np.cos(X)
Y3 = np.exp(X)
Y4 = X * X

plt.style.use("default")

fig, axs = plt.subplots(2,2, figsize=(10,8))
axs[0, 0].plot(X, Y1, color="green", linewidth="3", label="sin")
axs[0, 0].legend(loc="upper left")
axs[0, 0].xaxis.set_major_locator(ticker.NullLocator())
axs[0, 0].set_ylim(-1,1)
axs[0, 0].yaxis.set_major_locator(ticker.LinearLocator(numticks=3))
axs[0, 1].plot(X, Y2, color="red", linewidth="3", label="cos")
axs[0, 1].set_xlim(0,4*np.pi)
axs[0, 1].set_ylim(-1,1)
axs[0, 1].xaxis.set_major_locator(ticker.LinearLocator(numticks=5))
axs[0, 1].xaxis.set_major_formatter(ticker.PercentFormatter(xmax=2*np.pi))
axs[0, 1].legend(loc="upper left")
axs[1, 0].plot(X, Y3, color="blue", linewidth="3", label="exp(X)")
axs[1, 0].legend(loc="upper left")
axs[1, 0].set_yscale("log")
axs[1, 1].plot(X, Y4, color="orange", linewidth="3", label="X^2")
axs[1, 1].legend(loc="upper left")
fig.tight_layout()
fig.show()

# %%
X = np.linspace(0, 4*np.pi, 100)
Y1 = np.sin(X)
Y2 = np.cos(X)
Y3 = np.exp(X)
Y4 = X * X

plt.style.use("default")

fig, axs = plt.subplots(2,2, figsize=(10,8))
axs[0, 0].plot(X, Y1, color="green", linewidth="3", label="sin")
axs[0, 0].legend(loc="upper left")
axs[0, 0].xaxis.set_major_locator(ticker.NullLocator())
axs[0, 0].set_ylim(-1,1)
axs[0, 0].yaxis.set_major_locator(ticker.LinearLocator(numticks=3))
axs[0, 1].plot(X, Y2, color="red", linewidth="3", label="cos")
axs[0, 1].set_xlim(0,4*np.pi)
axs[0, 1].set_ylim(-1,1)
axs[0, 1].xaxis.set_major_locator(ticker.LinearLocator(numticks=5))
axs[0, 1].xaxis.set_major_formatter(ticker.PercentFormatter(xmax=2*np.pi))
axs[0, 1].xaxis.set_minor_locator(ticker.LinearLocator(numticks=9))
axs[0, 1].xaxis.set_tick_params(rotation=45)

axs[0, 1].xaxis.set_minor_formatter(ticker.PercentFormatter(xmax=2*np.pi))
axs[0, 1].legend(loc="upper left")
axs[1, 0].plot(X, Y3, color="blue", linewidth="3", label="exp(X)")
axs[1, 0].legend(loc="upper left")
axs[1, 0].set_yscale("log")
axs[1, 1].plot(X, Y4, color="orange", linewidth="3", label="X^2")
axs[1, 1].legend(loc="upper left")
fig.tight_layout()
fig.show()

# %%
X = np.arange(10)
Y1 = np.random.uniform(1, 10, 10)
Y2 = np.random.uniform(1, 10, 10)

fig, ax = plt.subplots()
ax.bar(X,Y1)
ax.bar(X,Y2)
fig.show()

# %%
X = np.arange(10)
Y1 = np.random.uniform(1, 10, 10)
Y2 = np.random.uniform(1, 10, 10)

fig, ax = plt.subplots()
ax.bar(X,Y1)
ax.bar(X,Y2, alpha=0.5)
fig.show()

# %%
width = 0.3

fig, ax = plt.subplots(figsize=(10,8))
ax.bar(X-width/2, Y1, width)
ax.bar(X+width/2, Y2, width)
fig.show()

# %%
width = 0.3

fig, ax = plt.subplots(figsize=(10,8))
ax.bar(X-width/2, Y1,width)
ax.bar(X+width/2, Y2,width, hatch="/")
fig.show()

# %%
width = 0.3

fig, ax = plt.subplots(figsize=(10,8))
ax.bar(X-width/2, Y1,width)

plt.rcParams['hatch.color'] = 'red'
plt.rcParams['hatch.linewidth'] = 8

ax.bar(X+width/2, Y2,width, hatch="/")
fig.show()

# %%
## https://matplotlib.org/3.1.1/gallery/mplot3d/surface3d.html

# This import registers the 3D projection, but is otherwise unused.
from mpl_toolkits.mplot3d import Axes3D  # noqa: F401 unused import

import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np


fig = plt.figure()
ax = fig.gca(projection='3d')

# Make data.
X = np.arange(-5, 5, 0.25)
Y = np.arange(-5, 5, 0.25)
X, Y = np.meshgrid(X, Y)
R = np.sqrt(X**2 + Y**2)
Z = np.sin(R)

# Plot the surface.
surf = ax.plot_surface(X, Y, Z, cmap=cm.coolwarm,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_zlim(-1.01, 1.01)
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))

# Add a color bar which maps values to colors.
fig.colorbar(surf, shrink=0.5, aspect=5)

plt.show()

# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt

mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.gca(projection='3d')
theta = np.linspace(-4 * np.pi, 4 * np.pi, 100)
z = np.linspace(-2, 2, 100)
r = z**2 + 1
x = r * np.sin(theta)
y = r * np.cos(theta)
ax.plot(x, y, z, label='parametric curve')
ax.legend()

plt.show()

# %%
fig.savefig("figure.png")
fig.savefig("figure.pdf")

# %%
# %cd /content/drive/My Drive/Colab Notebooks/2020-2-AITAP/4강
fig.savefig("figure.png")
fig.savefig("figure.pdf")

# %% [markdown]
# ## Reference
#
# https://matplotlib.org/3.1.1/tutorials/index.html
# https://matplotlib.org/3.1.1/index.html
# https://matplotlib.org/3.1.1/gallery/
# https://matplotlib.org/3.1.1/contents.html
